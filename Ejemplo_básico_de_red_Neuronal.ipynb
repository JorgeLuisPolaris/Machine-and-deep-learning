# %% [markdown]
# <a href="https://colab.research.google.com/github/JorgeLuisPolaris/Machine-and-deep-learning/blob/main/Ejemplo_b%C3%A1sico_de_red_Neuronal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importaciones
# ---
#
# Primer ejemplo de red neuronal con python tensorflow donde queremos que aprenda las reglas de una relación y= 2x-1.
#
# Comencemos con nuestras importaciones. Aquí estamos importando TensorFlow y lo llamamos tf para facilitar su uso.
#
# Luego importamos una biblioteca llamada numpy, que nos ayuda a representar nuestros datos como listas de manera fácil y rápida.
#
# El marco para definir una red neuronal como un conjunto de capas secuenciales se llama keras, por lo que también lo importamos.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# # Definir y compilar la red neuronal
# ---
# A continuación, crearemos la red neuronal más simple posible. Tiene 1 capa, y esa capa tiene 1 neurona, y la forma de entrada es solo 1 valor.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# Ahora compilamos nuestra red neuronal. Cuando lo hacemos, tenemos que especificar 2 funciones, una pérdida y un optimizador.
# Sabemos que en nuestra función, la relación entre los números es y = 2x-1.
#
# Cuando la computadora está tratando de 'aprender' eso, hace una suposición,tal vez y = 10x + 10. La función 'loss' mide las respuestas adivinadas contra las respuestas correctas conocidas y mide qué tan bien o qué tan mal lo hizo.
#
# Luego usa la función 'optimizer' para hacer otra conjetura. Según cómo fue la función de pérdida, intentará minimizar la pérdida. En ese punto, tal vez se le ocurra algo como y = 5x + 5, que, aunque sigue siendo bastante malo, está más cerca del resultado correcto (es decir, la pérdida es menor)
#
# Repetirá esto para el número de EPOCHS que verá en breve. Pero primero, así es como le decimos que use 'ERROR CUADRADO MEDIO' para la pérdida y 'DESCENSO DE GRADIENTE ESTOCÁSTICO' para el optimizador.

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# # Proporcionando los datos
# ---
#
# A continuación, incluiremos algunos datos. En este caso, estamos tomando 6 x's y 6y's. Puede ver que la relación entre estos es que y = 2x-1, entonces donde x = -1, y = -3 etc,etc.
#
# Una biblioteca de Python llamada 'Numpy' proporciona muchas estructuras de datos de tipo matriz que son una forma estándar de facto de hacerlo. Declaramos que queremos usarlos especificando los valores como np.array []

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# # Entrenando la red neuronal
# ---
# El proceso de entrenamiento de la red neuronal, donde "aprende" la relación entre las X y las Y, está en la llamada model.fit. Aquí es donde pasará por el ciclo del que se hablo anteriormente, haciendo una suposición, midiendo qué tan bueno o malo es (también conocido como la pérdida), usando el optimizer para hacer otra suposición, etc. Lo hará por la cantidad de 'epochs' que se elijan. Cuando ejecute este código, verá la pérdida en el lado derecho.

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 438ms/step - loss: 25.1521
# Epoch 2/500
# 1/1 [==============================] - 0s 5ms/step - loss: 20.0795
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 16.0826
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 12.9322
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 10.4479
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.4878
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9401
# Epoch 8/500
# 1/1 [==============================] - 0s 12ms/step - loss: 5.7171
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.7496
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.9833
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3753
# Epoch 12/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.8920
# ...

# %% [markdown]
# # Predicción
# ---
# Bien, ahora se tiene un modelo que ha sido entrenado para aprender la relación entre X e Y. Se hace uso del método model.predict para que calcule la Y para una X previamente desconocida. Entonces, por ejemplo, si X = 10.

# %%
  print(model.predict([10.0]))
# Out:
# [[18.979784]]

# %% [markdown]
# Las redes neuronales tratan con probabilidades, por lo que dados los datos con los que alimentamos al NN, calculó que existe una probabilidad muy alta de que la relación entre X e Y sea Y = 2X-1, pero con solo 6 puntos de datos no lo podemos saber con seguridad. Como resultado, el resultado de 10 está muy cerca de 19, pero no necesariamente 19.
